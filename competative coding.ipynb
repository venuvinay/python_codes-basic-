# %%
lenght=int(input())
breath=int(input())
print(lenght*breath)
# Out:
#  8
#  5
# 40

# %%
number=int(input())
rev=0
while number>0:
    digit=number%10
    rev=rev*10+digit
    number//=10
print(rev)
# Out:
#  1344
# 4431

# %%
n=int(input())
k=int(input())
if k%n==0:
    print(0)
else:
    print(k%n)
# Out:
#  3
#  14
# 2

# %%
a=int(input())
b=int(input())
c=int(input())
if (a+b)>c and (b+c)>a and (a+c)>b:
    print("yes")
else:
    print("no")
# Out:
#  9
#  15
#  2
# no

# %%
m=int(input())
if m%2==0 and m!=2:
    k=int(m/2)
    k1=int(m/2)
    if k%2==0 and k1%2==0:
        print("yes")
    else:
        k=k-1
        k1=k1+1
        if k%2==0 and k1%2==0 :
            print("yes")
else:
    print("no")
# Out:
#  14
# yes

# %%
x=int(input())
y=int(input())
if x%5==0:
    if y>x:
        m=y-x
        print(f'{m:.2f}')
    else:
        print(f'{y:.2f}')
else:
    print(f'{y:.2f}')
# Out:
#  42
#  120
# 120.00

# %% [markdown]
# x=100
# j=int(input())
# for i in range(j):
#     d=int(input())
#     m=(d/x)*x
#     print(x-m)

# %%
n1=int(input())
n2=int(input())
if n1>n2:
    print(n1-n2)
else:
    print(n1+n2)
# Out:
#  82
#  28
# 54

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b:
    print(a)
else:
    if b>c:
        print(c)
    else:
        print(b)
# Out:
#  11
#  400
#  120
# 120

# %%
n=int(input())
count=0
while n>0:
    digit=n%10
    if digit == 4:
        count+=1
    n//=10
print(count)
# Out:
#  44444235678994
# 6

# %%
n=int(input())
sum=0
for i in range(1,n+1):
    sum+=i
print(sum)
# Out:
#  4
# 10

# %%
n=int(input())
print(~n+16)
# Out:
#  5
# 10

# %%
n=int(input())
v=n//1000
b=n%10
print(v+b)
# Out:
#  1234
# 5

# %%
n=int(input())
rev=0
while n>0:
    digit=n%10
    rev=rev+digit
    n//=10
print(rev)
# Out:
#  1235
# 11

# %%
n=int(input())
if n%2==0:
    print(n+2)
else:
    print(n+1)
# Out:
#  7
# 8

# %%
x=100
n=int(input())
for i in range(n):
    h=int(input())
    m=(h/x)*x
    print(int(x-m))
# Out:
#  4
#  5
# 95
#  7
# 93
#  8
# 92
#  4
# 96

# %%
print(3//2)
# Out:
# 1
